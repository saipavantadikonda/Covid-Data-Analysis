# %% [markdown]
# ### Each student member creates notebooks to read the Enrichment data and displays them on a notebook:

# %% [markdown]
# Importing pandas library for reading csv&excel file and performing analysis on that data.

# %%
import pandas as pd

# %% [markdown]
# Reading covid excel file and displaying the Employement enrichment data set

# %%
employee_data= pd.read_excel("../../../../data/Stage_1/Silpa_data/Employee_data.xlsx")
employee_data
# Out:
#       Area\nCode   St  Cnty  Own  NAICS  Year  Qtr Area Type St Name  \
# 0          US000   US   0.0    0     10  2022    1    Nation     NaN
# 1          US000   US   0.0    1     10  2022    1    Nation     NaN
# 2          US000   US   0.0    2     10  2022    1    Nation     NaN
# 3          US000   US   0.0    3     10  2022    1    Nation     NaN
# 4          US000   US   0.0    5     10  2022    1    Nation     NaN
# ...          ...  ...   ...  ...    ...   ...  ...       ...     ...
# 62917      C4974  NaN   NaN    5   1024  2022    1       MSA     NaN
# 62918      C4974  NaN   NaN    5   1025  2022    1       MSA     NaN
# 62919      C4974  NaN   NaN    5   1026  2022    1       MSA     NaN
# 62920      C4974  NaN   NaN    5   1027  2022    1       MSA     NaN
# 62921      C4974  NaN   NaN    5   1029  2022    1       MSA     NaN
#
#                Area  ...                                 Industry Status Code  \
# ...

# %% [markdown]
# we are exporting  a Pandas DataFrame named "employee_data" to a .csv (Comma Separated Values) file format with the file name "employee_data.csv". The "index" argument with the value "False" is to prevent the DataFrame's index from being exported along with the data. This means that the resulting .csv file will only contain the actual data and not the row index values.

# %%
employee_data.to_csv("employee_data.csv,index=False")

# %% [markdown]
# Just describing the data type of each columns, it's important to know the data types of each column so we can properly analyze and manipulate the data.

# %%
employee_data.dtypes
# Out:
# Area\nCode                                        object
# St                                                object
# Cnty                                             float64
# Own                                                int64
# NAICS                                              int64
# Year                                               int64
# Qtr                                                int64
# Area Type                                         object
# St Name                                           object
# Area                                              object
# Ownership                                         object
# Industry                                          object
# Status Code                                       object
# Establishment Count                                int64
# January Employment                                 int64
# February Employment                                int64
# ...

# %%
employee_data
# Out:
#       Area\nCode   St  Cnty  Own  NAICS  Year  Qtr Area Type St Name  \
# 0          US000   US   0.0    0     10  2022    1    Nation     NaN
# 1          US000   US   0.0    1     10  2022    1    Nation     NaN
# 2          US000   US   0.0    2     10  2022    1    Nation     NaN
# 3          US000   US   0.0    3     10  2022    1    Nation     NaN
# 4          US000   US   0.0    5     10  2022    1    Nation     NaN
# ...          ...  ...   ...  ...    ...   ...  ...       ...     ...
# 62917      C4974  NaN   NaN    5   1024  2022    1       MSA     NaN
# 62918      C4974  NaN   NaN    5   1025  2022    1       MSA     NaN
# 62919      C4974  NaN   NaN    5   1026  2022    1       MSA     NaN
# 62920      C4974  NaN   NaN    5   1027  2022    1       MSA     NaN
# 62921      C4974  NaN   NaN    5   1029  2022    1       MSA     NaN
#
#                Area  ...                                 Industry Status Code  \
# ...
